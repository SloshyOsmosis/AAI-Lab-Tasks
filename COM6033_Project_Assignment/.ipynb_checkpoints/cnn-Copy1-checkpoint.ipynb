# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import normalize, img_to_array, to_categorical, load_img

# %%
class_names = ['GoldFinch', 'Magpie', 'Robin', 'Sparrow', 'Swan']

# %%
dataset_path = "BirdImages/"

batch_size = 64
seed = 1337
image_size = (128, 128)

# Initialize lists to store data and labels
data = []
labels = []

# Load class names
class_folders = os.listdir(dataset_path)  # Subfolders are class names
class_labels = {class_name: idx for idx, class_name in enumerate(class_folders)}

# Loop through each class folder and load images
for class_name in class_folders:
    class_folder = os.path.join(dataset_path, class_name)
    
    # Make sure the folder contains images (skip non-folder files)
    if os.path.isdir(class_folder):
        for image_file in os.listdir(class_folder):
            image_path = os.path.join(class_folder, image_file)
            
            # Load the image and preprocess
            img = load_img(image_path, target_size=image_size)  # Resize to desired shape
            img_array = img_to_array(img) / 255.0  # Normalize pixel values to [0, 1]
            data.append(img_array)
            
            # Append the label using class_labels dictionary
            labels.append(class_labels[class_name])

# %%
# Convert data and labels to numpy arrays
data = np.array(data)
labels = np.array(labels)

# One-hot encode labels
labels = to_categorical(labels, num_classes=len(class_names))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

X_train.shape
# Out:
# (4217, 128, 128, 3)

# %%
y_train.shape
# Out:
# (4217, 5)

# %%
X_test.shape
# Out:
# (1055, 128, 128, 3)

# %%
y_test.shape
# Out:
# (1055, 5)

# %%
index = np.random.choice(np.arange(len(X_train)), 24, replace=False)
figure, axes = plt.subplots(nrows=4, ncols=6, figsize=(16, 9))

for item in zip(axes.ravel(), X_train[index], y_train[index]):
    axes, image, target = item
    axes.imshow(image)
    axes.set_xticks([])  # Remove x-axis tick marks
    axes.set_yticks([])  # Remove y-axis tick marks
    
    # Convert one-hot encoded target back to class name
    target_idx = np.argmax(target)  # Find the index of the 1 in the one-hot vector
    bird_name = class_names[target_idx]  # Get the corresponding class name
    
    axes.set_title(bird_name)  # Set the title as the bird name

plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,                            
    zoom_range = 0.2,                              
    horizontal_flip = True)
train_datagen.fit(X_train)

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size = 64)

# %%
X_batch, y_batch = next(train_generator) 

figure, axes = plt.subplots(nrows=4, ncols=6, figsize=(16, 9))
index = np.random.choice(np.arange(len(X_batch)), 24, replace=False)

for item in zip(axes.ravel(), X_batch[index], y_batch[index]):
    axes, image, target = item
    axes.imshow(image)
    axes.set_xticks([])  # Remove x-axis tick marks
    axes.set_yticks([])  # Remove y-axis tick marks
    
    # Convert one-hot encoded target back to class name
    target_idx = np.argmax(target)  # Find the index of the 1 in the one-hot vector
    bird_name = class_names[target_idx]  # Get the corresponding class name
    
    axes.set_title(bird_name)  # Set the title as the bird name

plt.tight_layout()
plt.show()

# %%
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
print("X_train range:", X_train.min(), X_train.max())
print("X_test range:", X_test.min(), X_test.max())
# Out:
# X_train range: 0.0 1.0
# X_test range: 0.0 1.0

# %%
y_train[0]
# Out:
# array([0., 0., 1., 0., 0.], dtype=float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

activation = 'relu'
model = Sequential()
model.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (128, 128, 3),
                 kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())

model.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform',
                 kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D())

model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform',
                 kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform',
                 kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization()) 
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(128, activation = activation, kernel_initializer = 'he_uniform'))
model.add(Dropout(0.4))
model.add(Dense(5, activation = 'softmax'))

learning_rate = 0.001  # You can adjust this value as needed
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer = optimizer,loss = 'categorical_crossentropy', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  dropout (Dropout)           (None, 64, 64, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 8,455,717
# Trainable params: 8,455,333
# Non-trainable params: 384
# _________________________________________________________________
# None

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/30
# 132/132 [==============================] - 75s 561ms/step - loss: 7.2351 - accuracy: 0.2919 - val_loss: 15.7147 - val_accuracy: 0.2919
# Epoch 2/30
# 132/132 [==============================] - 71s 542ms/step - loss: 4.1240 - accuracy: 0.3450 - val_loss: 33.2669 - val_accuracy: 0.2502
# Epoch 3/30
# 132/132 [==============================] - 72s 545ms/step - loss: 3.5943 - accuracy: 0.3728 - val_loss: 14.5070 - val_accuracy: 0.3431
# Epoch 4/30
# 132/132 [==============================] - 72s 546ms/step - loss: 3.3573 - accuracy: 0.3223 - val_loss: 17.5970 - val_accuracy: 0.2777
# Epoch 5/30
# 132/132 [==============================] - 74s 563ms/step - loss: 3.0155 - accuracy: 0.3512 - val_loss: 4.2314 - val_accuracy: 0.4284
# Epoch 6/30
# 132/132 [==============================] - 73s 550ms/step - loss: 2.6612 - accuracy: 0.3775 - val_loss: 2.7092 - val_accuracy: 0.4626
# Epoch 7/30
# 132/132 [==============================] - 72s 547ms/step - loss: 2.3669 - accuracy: 0.4389 - val_loss: 4.1273 - val_accuracy: 0.4834
# Epoch 8/30
# 132/132 [==============================] - 74s 558ms/step - loss: 2.1811 - accuracy: 0.4328 - val_loss: 2.1199 - val_accuracy: 0.4919
# Epoch 9/30
# 132/132 [==============================] - 77s 586ms/step - loss: 2.0765 - accuracy: 0.4313 - val_loss: 2.1592 - val_accuracy: 0.3280
# Epoch 10/30
# 132/132 [==============================] - 76s 575ms/step - loss: 1.8486 - accuracy: 0.4676 - val_loss: 1.6987 - val_accuracy: 0.5877
# Epoch 11/30
# 132/132 [==============================] - 74s 564ms/step - loss: 1.7100 - accuracy: 0.4994 - val_loss: 1.4962 - val_accuracy: 0.6095
# Epoch 12/30
# 132/132 [==============================] - 74s 560ms/step - loss: 1.5968 - accuracy: 0.5037 - val_loss: 1.5805 - val_accuracy: 0.5668
# Epoch 13/30
# 132/132 [==============================] - 83s 627ms/step - loss: 1.5158 - accuracy: 0.5124 - val_loss: 1.3778 - val_accuracy: 0.6190
# Epoch 14/30
# 132/132 [==============================] - 73s 551ms/step - loss: 1.3950 - accuracy: 0.5502 - val_loss: 1.4505 - val_accuracy: 0.5526
# Epoch 15/30
# 132/132 [==============================] - 72s 548ms/step - loss: 1.3648 - accuracy: 0.5525 - val_loss: 1.2699 - val_accuracy: 0.6616
# Epoch 16/30
# 132/132 [==============================] - 72s 549ms/step - loss: 1.2581 - accuracy: 0.5622 - val_loss: 1.0828 - val_accuracy: 0.6569
# Epoch 17/30
# 132/132 [==============================] - 75s 567ms/step - loss: 1.2593 - accuracy: 0.5687 - val_loss: 1.3327 - val_accuracy: 0.5716
# Epoch 18/30
# 132/132 [==============================] - 72s 549ms/step - loss: 1.2264 - accuracy: 0.5824 - val_loss: 1.3020 - val_accuracy: 0.5867
# Epoch 19/30
# 132/132 [==============================] - 74s 559ms/step - loss: 1.1354 - accuracy: 0.6026 - val_loss: 1.0617 - val_accuracy: 0.7071
# Epoch 20/30
# 132/132 [==============================] - 72s 542ms/step - loss: 1.1272 - accuracy: 0.6078 - val_loss: 1.0588 - val_accuracy: 0.6872
# Epoch 21/30
# 132/132 [==============================] - 73s 557ms/step - loss: 1.0794 - accuracy: 0.6177 - val_loss: 1.0979 - val_accuracy: 0.6664
# Epoch 22/30
# 132/132 [==============================] - 74s 563ms/step - loss: 1.0531 - accuracy: 0.6374 - val_loss: 0.9720 - val_accuracy: 0.6900
# Epoch 23/30
# 132/132 [==============================] - 72s 547ms/step - loss: 1.1067 - accuracy: 0.6249 - val_loss: 1.4532 - val_accuracy: 0.5517
# Epoch 24/30
# 132/132 [==============================] - 75s 568ms/step - loss: 1.1203 - accuracy: 0.6291 - val_loss: 1.3353 - val_accuracy: 0.5431
# Epoch 25/30
# 132/132 [==============================] - 80s 608ms/step - loss: 1.0538 - accuracy: 0.6469 - val_loss: 0.9052 - val_accuracy: 0.7270
# Epoch 26/30
# 132/132 [==============================] - 80s 610ms/step - loss: 0.9796 - accuracy: 0.6656 - val_loss: 1.1408 - val_accuracy: 0.6389
# Epoch 27/30
# 132/132 [==============================] - 74s 561ms/step - loss: 1.0599 - accuracy: 0.6602 - val_loss: 1.2843 - val_accuracy: 0.5943
# Epoch 28/30
# 132/132 [==============================] - 76s 577ms/step - loss: 0.9536 - accuracy: 0.6773 - val_loss: 2.0596 - val_accuracy: 0.5962
# Epoch 29/30
# 132/132 [==============================] - 77s 582ms/step - loss: 1.0661 - accuracy: 0.6609 - val_loss: 1.0777 - val_accuracy: 0.6739
# Epoch 30/30
# 132/132 [==============================] - 76s 579ms/step - loss: 0.9325 - accuracy: 0.6832 - val_loss: 0.9635 - val_accuracy: 0.7109

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 loss, accuracy = model.evaluate(val_ds)
#       2 print(f"Validation Accuracy: {accuracy*100:.2f}%")
#
# NameError: name 'val_ds' is not defined

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical

# Step 1: Get model predictions on the test set
y_pred = model.predict(X_test)

# Step 2: Convert one-hot encoded predictions and true labels to class labels
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert predicted probabilities to class indices
y_true_classes = np.argmax(y_test, axis=1)  # Convert true labels to class indices

# Step 3: Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Step 4: Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 33/33 [==============================] - 4s 100ms/step

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
image_size = (128, 128)
# Load and preprocess the image
img = load_img("BirdImages/Magpie/0F3YTTCKF0R0.jpg", target_size=image_size)
img_array = img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Add batch axis
img_array = img_array / 255.0  # Normalize the image (as done during training)

# Predict the bird class
predictions = model.predict(img_array)

# Retrieve the class with the highest probability
predicted_index = np.argmax(predictions[0])  # Index of the predicted class
confidence = predictions[0][predicted_index] * 100  # Confidence percentage
# Display the predicted bird species and confidence
print(f"This image is most likely a {class_names[predicted_index]} with a confidence of {confidence:.2f}%.")
# Out:
# 1/1 [==============================] - 0s 29ms/step
# This image is most likely a Magpie with a confidence of 56.25%.

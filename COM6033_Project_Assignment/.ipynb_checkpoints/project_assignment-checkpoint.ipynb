# %% [markdown]
# This project aims to develop a machine learning algorithm that is capable of classifying images of common bird found in the UK. The algorithm aims to distinguish the physical differences between the 5 birds.

# %% [markdown]
# Importing

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
Batch_Size = 64
Seed = 1337
image_size = (128, 128)

train_ds = tf.keras.utils.image_dataset_from_directory(
    "BirdImages/",
    validation_split=0.2,
    subset="training",
    seed=Seed,
    shuffle=True,
    image_size=image_size,
    batch_size=Batch_Size,
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "BirdImages/",
    validation_split=0.2,
    subset="validation",
    seed=Seed,
    shuffle=False,
    image_size=image_size,
    batch_size=Batch_Size,
)
# Out:
# Found 8067 files belonging to 5 classes.
# Using 6454 files for training.
# Found 8067 files belonging to 5 classes.
# Using 1613 files for validation.

# %%
# Extract class names before applying transformations
class_names = train_ds.class_names
print(f"Class names: {class_names}")

# Apply prefetching (if necessary) for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Class names: ['Goldfinch', 'Magpie', 'Robin', 'Sparrow', 'Swan']

# %%
iterator = iter(train_ds)
next(iterator)[0][0].numpy().shape
# Out:
# (128, 128, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(next(iterator)[0][0].numpy().astype(np.int32))

# %% [markdown]
# Data Augmentation
#
# Currently in the dataset, there are around 1200-1400 images in each folder except for the 'sparrow' folder which only has 800 images. To address this I am going to perform data augmentation to create more images for the model to work with to ensure a uniform dataset spread.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img, img_to_array


dataGen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

img_path = 'BirdImages/Sparrow/0LL4O0ZH6JG3.jpg'
img = load_img(img_path)  
img = img_to_array(img)  
img = img.reshape((1,) + img.shape) 

augmented_images = []
for batch in dataGen.flow(img, batch_size=1):
    augmented_images.append(batch[0].astype('uint8'))
    if len(augmented_images) >=9:
        break

for i, img in enumerate(augmented_images):
    plt.subplot(3,3, i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img, img_to_array
import random

dataGen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

#Identify folder path
folder_path = 'BirdImages/Sparrow/'

#Listing images labeled with 'jpg' in the sparrow folder
image_files = [f for f in os.listdir(folder_path) if f.endswith('.jpg')]

#Randomly selects images for augmentation
selected_images = random.sample(image_files, 10)

for image_file in selected_images:
    img_path = os.path.join(folder_path,image_file)
    img = load_img(img_path)
    img = img_to_array(img) 
    img = img.reshape((1,) + img.shape)
    augmented_images = []
    for batch in dataGen.flow(img, batch_size=1):
        augmented_images.append(batch[0].astype('uint8'))
        if len(augmented_images) >=9:
            break

    for i, img in enumerate(augmented_images):
        plt.subplot(3,3, i+1)
        plt.imshow(img)
        plt.axis('off')
    plt.show()

# %%
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
val_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3), kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    GlobalAveragePooling2D(),

    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  global_average_pooling2d_1   (None, 32)               0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 128)               4224
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,829
# Trainable params: 13,765
# Non-trainable params: 64
# _________________________________________________________________

# %%
from tensorflow.keras.metrics import *
from tensorflow.keras.losses import SparseCategoricalCrossentropy

metrics = ['accuracy', Precision(), Recall(), AUC()]

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

model.compile(loss=SparseCategoricalCrossentropy(),
              optimizer=Adam(learning_rate=0.001),
              metrics=metrics)

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=3, monitor='val_loss')

# %%
for images, labels in train_ds.take(1):
    print(labels.shape)
    print(labels[0])
# Out:
# (16,)
# tf.Tensor(2, shape=(), dtype=int32)

# %%
history = model.fit(
    train_ds,  # Training dataset
    validation_data=val_ds,  # Validation dataset
    epochs=25,  # Number of epochs (you can adjust this)
    batch_size=32  # Batch size (this is already set in the dataset loader)
)
# Out:
# Epoch 1/25
# 101/101 [==============================] - 35s 334ms/step - loss: 1.4885 - accuracy: 0.3944 - val_loss: 1.6280 - val_accuracy: 0.3169
# Epoch 2/25
# 101/101 [==============================] - 34s 339ms/step - loss: 1.3639 - accuracy: 0.4837 - val_loss: 1.7383 - val_accuracy: 0.3386
# Epoch 3/25
# 101/101 [==============================] - 34s 335ms/step - loss: 1.2768 - accuracy: 0.5267 - val_loss: 1.2696 - val_accuracy: 0.5373
# Epoch 4/25
# 101/101 [==============================] - 33s 330ms/step - loss: 1.2115 - accuracy: 0.5487 - val_loss: 1.1977 - val_accuracy: 0.5560
# Epoch 5/25
# 101/101 [==============================] - 34s 335ms/step - loss: 1.1304 - accuracy: 0.5932 - val_loss: 1.3803 - val_accuracy: 0.5131
# Epoch 6/25
# 101/101 [==============================] - 34s 335ms/step - loss: 1.0831 - accuracy: 0.6058 - val_loss: 1.1890 - val_accuracy: 0.5768
# Epoch 7/25
# 101/101 [==============================] - 33s 329ms/step - loss: 1.0453 - accuracy: 0.6315 - val_loss: 1.0597 - val_accuracy: 0.6321
# Epoch 8/25
# 101/101 [==============================] - 34s 340ms/step - loss: 1.0066 - accuracy: 0.6450 - val_loss: 1.0515 - val_accuracy: 0.6103
# Epoch 9/25
# 101/101 [==============================] - 33s 328ms/step - loss: 0.9829 - accuracy: 0.6555 - val_loss: 1.1321 - val_accuracy: 0.5709
# Epoch 10/25
# 101/101 [==============================] - 34s 339ms/step - loss: 0.9697 - accuracy: 0.6561 - val_loss: 0.9340 - val_accuracy: 0.6722
# Epoch 11/25
# 101/101 [==============================] - 34s 334ms/step - loss: 0.9522 - accuracy: 0.6639 - val_loss: 1.1380 - val_accuracy: 0.5807
# Epoch 12/25
# 101/101 [==============================] - 33s 330ms/step - loss: 0.9589 - accuracy: 0.6667 - val_loss: 1.0776 - val_accuracy: 0.6068
# Epoch 13/25
# 101/101 [==============================] - 34s 333ms/step - loss: 0.9297 - accuracy: 0.6667 - val_loss: 0.8831 - val_accuracy: 0.6941
# Epoch 14/25
# 101/101 [==============================] - 33s 327ms/step - loss: 0.9047 - accuracy: 0.6811 - val_loss: 0.8757 - val_accuracy: 0.6978
# Epoch 15/25
# 101/101 [==============================] - 41s 409ms/step - loss: 0.9010 - accuracy: 0.6898 - val_loss: 0.8993 - val_accuracy: 0.6958
# Epoch 16/25
# 101/101 [==============================] - 36s 353ms/step - loss: 0.8913 - accuracy: 0.6904 - val_loss: 1.0228 - val_accuracy: 0.6284
# Epoch 17/25
# 101/101 [==============================] - 32s 314ms/step - loss: 0.8666 - accuracy: 0.6936 - val_loss: 0.8825 - val_accuracy: 0.6927
# Epoch 18/25
# 101/101 [==============================] - 31s 308ms/step - loss: 0.8684 - accuracy: 0.6943 - val_loss: 0.9229 - val_accuracy: 0.6718
# Epoch 19/25
# 101/101 [==============================] - 31s 304ms/step - loss: 0.8620 - accuracy: 0.6998 - val_loss: 0.9824 - val_accuracy: 0.6423
# Epoch 20/25
# 101/101 [==============================] - 31s 306ms/step - loss: 0.8490 - accuracy: 0.7074 - val_loss: 0.9587 - val_accuracy: 0.6464
# Epoch 21/25
# 101/101 [==============================] - 31s 308ms/step - loss: 0.8294 - accuracy: 0.7111 - val_loss: 0.9906 - val_accuracy: 0.6400
# Epoch 22/25
# 101/101 [==============================] - 31s 301ms/step - loss: 0.8374 - accuracy: 0.7054 - val_loss: 0.8524 - val_accuracy: 0.7046
# Epoch 23/25
# 101/101 [==============================] - 31s 301ms/step - loss: 0.8247 - accuracy: 0.7177 - val_loss: 0.8433 - val_accuracy: 0.7015
# Epoch 24/25
# 101/101 [==============================] - 31s 308ms/step - loss: 0.8224 - accuracy: 0.7158 - val_loss: 0.8257 - val_accuracy: 0.7183
# Epoch 25/25
# 101/101 [==============================] - 31s 311ms/step - loss: 0.8167 - accuracy: 0.7150 - val_loss: 1.1893 - val_accuracy: 0.5890

# %%
loss, accuracy = model.evaluate(val_ds)
print(f"Validation Accuracy: {accuracy*100:.2f}%")
# Out:
# 101/101 [==============================] - 8s 76ms/step - loss: 1.1893 - accuracy: 0.5890
# Validation Accuracy: 58.90%

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

# Load and preprocess the image
img = load_img("BirdImages/GoldFinch/0HC52ETAGUWF.jpg", target_size=image_size)
img_array = img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Add batch axis
img_array = img_array / 255.0  # Normalize the image (as done during training)

# Predict the bird class
predictions = model.predict(img_array)

# Retrieve the class with the highest probability
predicted_index = np.argmax(predictions[0])  # Index of the predicted class
confidence = predictions[0][predicted_index] * 100  # Confidence percentage
# Display the predicted bird species and confidence
print(f"This image is most likely a {class_names[predicted_index]} with a confidence of {confidence:.2f}%.")
# Out:
# 1/1 [==============================] - 0s 22ms/step
# This image is most likely a Swan with a confidence of 99.73%.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Get predictions
y_true = np.concatenate([y for x, y in val_ds])
y_pred = np.argmax(model.predict(val_ds), axis=1)

# Confusion matrix and classification report
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       4 # Get predictions
# ----> 5 y_true = np.concatenate([y for x, y in val_ds])
#       6 y_pred = np.argmax(model.predict(val_ds), axis=1)
#       8 # Confusion matrix and classification report
#
# NameError: name 'val_ds' is not defined
